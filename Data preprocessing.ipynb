# %%
import pandas as pd

# %%
ebay_df = pd.read_csv("ebay.csv")

# %%
ebay_df.head()
# Out:
#   x-refine__item            clipped        icon href  \
# 0       Category  Selected category              NaN
# 1      Condition          (3) Items  [object Object]
# 2          Price                NaN  [object Object]
# 3  Buying Format                NaN  [object Object]
# 4  Item Location                NaN  [object Object]
#
#                                             cbx href checkbox__unchecked href  \
# 0                                                NaN                      NaN
# 1  https://www.ebay.com/sch/i.html?_from=R40&_nkw...          [object Object]
# 2  https://www.ebay.com/sch/i.html?_from=R40&_nkw...          [object Object]
# 3                                                NaN                      NaN
# 4                                                NaN                      NaN
#
#              cbx x-refine__multi-select-histogram fake-link  \
# 0            NaN                              NaN       NaN
# ...

# %%
ebay_df.head(5)
# Out:
#   x-refine__item            clipped        icon href  \
# 0       Category  Selected category              NaN
# 1      Condition          (3) Items  [object Object]
# 2          Price                NaN  [object Object]
# 3  Buying Format                NaN  [object Object]
# 4  Item Location                NaN  [object Object]
#
#                                             cbx href checkbox__unchecked href  \
# 0                                                NaN                      NaN
# 1  https://www.ebay.com/sch/i.html?_from=R40&_nkw...          [object Object]
# 2  https://www.ebay.com/sch/i.html?_from=R40&_nkw...          [object Object]
# 3                                                NaN                      NaN
# 4                                                NaN                      NaN
#
#              cbx x-refine__multi-select-histogram fake-link  \
# 0            NaN                              NaN       NaN
# ...

# %%
ebay_df.tail()
# Out:
#      x-refine__item clipped        icon href  \
# 3     Buying Format     NaN  [object Object]
# 4     Item Location     NaN  [object Object]
# 5  Shipping Options     NaN  [object Object]
# 6      Local Pickup     NaN  [object Object]
# 7         Show only     NaN  [object Object]
#
#                                             cbx href checkbox__unchecked href  \
# 3                                                NaN                      NaN
# 4                                                NaN                      NaN
# 5  https://www.ebay.com/sch/i.html?_from=R40&_nkw...          [object Object]
# 6  https://www.ebay.com/sch/i.html?_from=R40&_nkw...          [object Object]
# 7  https://www.ebay.com/sch/i.html?_from=R40&_nkw...          [object Object]
#
#                            cbx x-refine__multi-select-histogram fake-link  \
# 3                 All Listings                              (3)   see all
# ...

# %%
print(ebay_df.isnull().sum())
# Out:
# x-refine__item                      0
# clipped                             6
# icon href                           1
# cbx href                            3
# checkbox__unchecked href            3
# cbx                                 1
# x-refine__multi-select-histogram    6
# fake-link                           1
# cbx href 2                          6
# checkbox__unchecked href 2          6
# cbx 2                               4
# cbx href 3                          6
# cbx 3                               4
# rbx href                            6
# radio__unchecked href               6
# rbx href 2                          6
# rbx href 3                          6
# cbx 4                               5
# dtype: int64

# %%
ebay_df.clipped = ebay_df.clipped.fillna("unknown")
print(ebay_df.isnull().sum())
# Out:
# x-refine__item                      0
# clipped                             0
# icon href                           1
# cbx href                            3
# checkbox__unchecked href            3
# cbx                                 1
# x-refine__multi-select-histogram    6
# fake-link                           1
# cbx href 2                          6
# checkbox__unchecked href 2          6
# cbx 2                               4
# cbx href 3                          6
# cbx 3                               4
# rbx href                            6
# radio__unchecked href               6
# rbx href 2                          6
# rbx href 3                          6
# cbx 4                               5
# dtype: int64

# %%
print(ebay_df.shape)
# Out:
# (8, 18)

# %%
print(ebay_df.dtypes)
# Out:
# x-refine__item                      object
# clipped                             object
# icon href                           object
# cbx href                            object
# checkbox__unchecked href            object
# cbx                                 object
# x-refine__multi-select-histogram    object
# fake-link                           object
# cbx href 2                          object
# checkbox__unchecked href 2          object
# cbx 2                               object
# cbx href 3                          object
# cbx 3                               object
# rbx href                            object
# radio__unchecked href               object
# rbx href 2                          object
# rbx href 3                          object
# cbx 4                               object
# dtype: object

# %%
ebay_df.dropna(axis = 0, inplace = True)

# %%
print(ebay_df.isnull().sum())
# Out:
# x-refine__item                      0.0
# clipped                             0.0
# icon href                           0.0
# cbx href                            0.0
# checkbox__unchecked href            0.0
# cbx                                 0.0
# x-refine__multi-select-histogram    0.0
# fake-link                           0.0
# cbx href 2                          0.0
# checkbox__unchecked href 2          0.0
# cbx 2                               0.0
# cbx href 3                          0.0
# cbx 3                               0.0
# rbx href                            0.0
# radio__unchecked href               0.0
# rbx href 2                          0.0
# rbx href 3                          0.0
# cbx 4                               0.0
# dtype: float64
